# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
f, (ax_1, ax_2) = plt.subplots(2,1,figsize=(9,6))
metrics_second = np.array([410951.96,  545209.05, 172888.83, 256474.51])
rows_second = np.array([82190.18,  68952.01, 34577.68, 32436.06])


labels = np.array(["Timescale_4_workers","Influx_4_workers","Timescale_1_worker","Influx_1_worker"])

ax_1.bar(labels,metrics_second, color=['royalblue', 'orchid', 'royalblue', 'orchid'])
ax_2.bar(labels,rows_second, color=['royalblue', 'orchid', 'royalblue', 'orchid'])
f.suptitle("Small Dataset IoT Insert Performance")


ax_1.set_ylabel("Metrics / second")
ax_2.set_ylabel("Rows / second")
ax_2.set_xlabel("Database_Workers")
# Out:
# Text(0.5, 0, 'Database_Workers')

# %%
f, (ax_1, ax_2) = plt.subplots(2,1,figsize=(9,6))
metrics_second = np.array([274507.56,  557270.87, 139015.04, 247604.41])
rows_second = np.array([54902.42,  70481.0, 27803.47, 31315.84])


labels = np.array(["Timescale_4_workers","Influx_4_workers","Timescale_1_worker","Influx_1_worker"])

ax_1.bar(labels,metrics_second, color=['royalblue', 'orchid', 'royalblue', 'orchid'])
ax_2.bar(labels,rows_second, color=['royalblue', 'orchid', 'royalblue', 'orchid'])
f.suptitle("Medium Dataset IoT Insert Performance")



ax_1.set_ylabel("Metrics / second")
ax_2.set_ylabel("Rows / second")
ax_2.set_xlabel("Database_Workers")
# Out:
# Text(0.5, 0, 'Database_Workers')

# %%
f, (ax_1, ax_2) = plt.subplots(2,1,figsize=(9,6))
metrics_second = np.array([337228.62,  539350.81, 153876.47, 2937528.56])
rows_second = np.array([67446.75,  68215.22, 30775.77, 371528.45])


labels = np.array(["Timescale_4_workers","Influx_4_workers","Timescale_1_worker","Influx_1_worker"])

ax_1.bar(labels,metrics_second, color=['royalblue', 'orchid', 'royalblue', 'orchid'])
ax_2.bar(labels,rows_second, color=['royalblue', 'orchid', 'royalblue', 'orchid'])
f.suptitle("Large Dataset IoT Insert Performance")


ax_1.set_ylabel("Metrics / second")
ax_2.set_ylabel("Rows / second")
ax_2.set_xlabel("Database_Workers")
# Out:
# Text(0.5, 0, 'Database_Workers')

# %%
f, (ax_1, ax_2, ax_3) = plt.subplots(3,1,figsize=(9,11))
disk_size_small= np.array([727,  99])
disk_size_medium = np.array([3579,  367])
disk_size_large = np.array([13000, 1300])

labels = np.array(["Timescale_Db","Influx"])

ax_1.bar(labels,disk_size_small, color=['royalblue', 'orchid'])
ax_2.bar(labels,disk_size_medium, color=['royalblue', 'orchid'])
ax_3.bar(labels,disk_size_large, color=['royalblue', 'orchid'])
ax_1.set_title("Disk Size Comparison")


ax_1.set_ylabel("Mb")
ax_1.set_xlabel("Small Dataset Disk Size")
ax_2.set_ylabel("Mb")
ax_2.set_xlabel("Medium Dataset Disk Size")
ax_3.set_ylabel("Mb")
ax_3.set_xlabel("Large Dataset Disk Size")
# Out:
# Text(0.5, 0, 'Large Dataset Disk Size')

# %%
#influx
avg_query_duration_IoT_influx_small = (0.37 + 1.53 + 0.53 + 10.80 + 15.54 + 39.72 + 16.44 + 3.47)/8
avg_query_duration_IoT_influx_medium = (0.13 + 0.09 + 0.42 + 0.11 + 4.96 +  5.45 + 4.47 + 20.79 + 7.21 + 1.61)/ 10
avg_query_duration_IoT_influx_large = (0.04 +  0.02 + 0.16 + 0.03 + 2.60 + 3.38 + 1.54 + 6.08 + 6.06 + 0.69)/10

avg_query_duration_devops_influx_small = ( 671.93 + 405.89 + 15.06 +  2.40 + 1.39 + 1.88 + 1355.84 + 2.02 + 15.56 + 705.68 + 558.49 + 1298.61 + 1161.86 + 1182.11 + 910.77)/15
avg_query_duration_devops_influx_medium = (94.14 + 360.28 + 9.36 + 2.20 +   1.17 +  0.32 + 852.39 + 1.82  + 813.44 + 1115.05 + 825.57 + 1090.53 + 700.02 + 525.79  )/14
avg_query_duration_devops_influx_large = (18.56 + 433.54 + 8.97 + 2.52 + 1.22 +  0.10 + 1105.14 + 2.06 + 3.97 + 1002.96 + 626.39 + 1083.53 + 1024.35 + 1531.45 + 990.71 )/ 15

# %%
#timescale
avg_query_duration_IoT_influx_small = (0.37 + 1.53 + 0.53 + 10.80 + 15.54 + 39.72 + 16.44 + 3.47)/8
avg_query_duration_IoT_timescale_small = (6.46 + 3.87 + 1.56 + 0.06 + 0.06 + 7.07 + 0.06 + 354.81)/8

avg_query_duration_IoT_influx_medium = (0.13 + 0.09 + 0.42 + 0.11 + 4.96 +  5.45 + 4.47 + 20.79 + 7.21 + 1.61)/ 10
avg_query_duration_IoT_timescale_medium = (0.29 +   0.19  + 0.11 +  0.07  + 0.01 + 0.05 + 0.64 + 6.45 + 0.05 + 80.82 )/10

avg_query_duration_IoT_influx_large = (0.04 +  0.02 + 0.16 + 0.03 + 2.60 + 3.38 + 1.54 + 6.08 + 6.06 + 0.69)/10
avg_query_duration_IoT_timescale_large = (0.22 + 0.08 +  0.02 + 0.43 + 0.03 )/5



avg_query_duration_devops_influx_small = ( 671.93 + 405.89 + 15.06 +  2.40 + 1.39 + 1.88 + 1355.84 + 2.02 + 15.56 + 705.68 + 558.49 + 1298.61 + 1161.86 + 1182.11 + 910.77)/15
avg_query_duration_devops_timescale_small = (597.82 + 246.83 + 31.44 + 10.01 + 7.93 + 671.81 + 475.82 + 52.16 + 0.63 + 691.13 +  265.62 + 672.20 + 760.29 + 231.43 +  603.98)/15


avg_query_duration_devops_influx_medium =    (94.14 + 360.28 + 9.36 + 2.20 +   1.17 +  0.32 + 852.39 + 1.82  + 813.44 + 1115.05 + 825.57 + 1090.53 + 700.02 + 525.79  )/14
avg_query_duration_devops_timescale_medium = ( 417.04 + 154.63 + 16.56 + 9.88 +  8.19 + 234.30  + 334.33 + 43.92  + 728.51 + 218.23 + 590.54 + 576.93 + 200.64 + 136.68 ) /14


avg_query_duration_devops_influx_large =     (18.56 + 433.54 + 8.97 + 2.52 + 1.22 +  0.10 + 1105.14 + 2.06 + 3.97 + 1002.96 + 626.39 + 1083.53 + 1024.35 + 1531.45 + 990.71 )/ 15
avg_query_duration_devops_timescale_large = ( 207.86 +  85.41 +  31.12 + 9.96 + 8.22 + 215.64 + 249.57 + 34.08 + 0.78 +  670.44 + 203.68 + 489.54 + 653.91 + 214.95 + 496.73) /15

# %%
influx_devops_small_percentage = 10/15
timescale_devops_small_percentage = 5/15
influx_devops_medium_percentage = 8/14
timescale_devops_medium_percentage = 6/14
influx_devops_large_percentage = 9/15
timescale_devops_large_percentage = 6/15

# %%
large_double_group_by_timescale = (31.12 + 9.96 + 8.22 + 215.64)/4
large_double_group_by_influx = (8.97 + 2.52 + 1.22 +  0.10)/4

large_single_group_by_influx = (1002.96 + 626.39 + 1083.53 + 1024.35 + 1531.45 + 990.71)/6
large_single_group_by_timescale = (670.44 + 203.68 + 489.54 + 653.91 + 214.95 + 496.73) /6

# %%
f, (ax_1, ax_2) = plt.subplots(2,1,figsize=(7,7))
metrics_second = np.array([large_double_group_by_timescale ,  large_double_group_by_influx])
rows_second = np.array([large_single_group_by_timescale,  large_single_group_by_influx])


labels = np.array(["Timescale","Influx"])

ax_1.bar(labels,metrics_second, color=['royalblue', 'orchid'])
ax_2.bar(labels,rows_second, color=['royalblue', 'orchid'])
ax_1.set_title("Average Query Rate of Double Group-by Queries for Large Dataset")
ax_2.set_title("Average Query Rate of Single Group-by Queries for Large Dataset")

ax_1.set_ylabel("Queries/ second")
ax_2.set_ylabel("Queries / second")
# Out:
# Text(0, 0.5, 'Queries / second')

# %%
f, ax_1 = plt.subplots(1,1,figsize=( 10,3))
query_rate_small= np.array([ timescale_devops_small_percentage, influx_devops_small_percentage , timescale_devops_medium_percentage, influx_devops_medium_percentage , timescale_devops_large_percentage, influx_devops_large_percentage])

labels = np.array(["Timescale_Small","Influx_Small", 'Timescale_Medium', 'Influx_Medium', 'Timescale_Large', 'Influx_Large'])

ax_1.bar(labels,query_rate_small, color=['royalblue', 'orchid'])

ax_1.set_title("Percentage of greater query rate per database size")


ax_1.set_ylabel('Greater Query Rate/ Total Queries')
ax_1.set_xlabel("Database")
# Out:
# Text(0.5, 0, 'Database')

# %%
f, (ax_1, ax_2, ax_3) = plt.subplots(3,1,figsize=(9,11))
query_rate_small= np.array([671.81, 1.88])
query_rate_medium = np.array([234.30, 0.32])
query_rate_large = np.array([ 215.64 , 0.10])

labels = np.array(["Timescale_Db","Influx"])

ax_1.bar(labels,query_rate_small, color=['royalblue', 'orchid'])
ax_2.bar(labels,query_rate_medium, color=['royalblue', 'orchid'])
ax_3.bar(labels,query_rate_large, color=['royalblue', 'orchid'])
ax_1.set_title("Query Rate for Groupby-Orderby-Limit")


ax_1.set_ylabel("Queries/second")
ax_1.set_xlabel("Small Dataset Query Rate")
ax_2.set_ylabel("Queries/second")
ax_2.set_xlabel("Medium Dataset Query Rate")
ax_3.set_ylabel("Queries/second")
ax_3.set_xlabel("Large Dataset   Query Rate")
# Out:
# Text(0.5, 0, 'Large Dataset   Query Rate')

# %%
f, (ax_1, ax_2, ax_3) = plt.subplots(3,1,figsize=(9,11))
query_rate_small= np.array([0.06, 16.44])
query_rate_medium = np.array([0.05,7.21])
query_rate_large = np.array([ 0.03 , 6.06])

labels = np.array(["Timescale_Db","Influx"])

ax_1.bar(labels,query_rate_small, color=['royalblue', 'orchid'])
ax_2.bar(labels,query_rate_medium, color=['royalblue', 'orchid'])
ax_3.bar(labels,query_rate_large, color=['royalblue', 'orchid'])
ax_1.set_title("Query Rate for Low Fuel")


ax_1.set_ylabel("Queries/second")
ax_1.set_xlabel("Small Dataset Query Rate")
ax_2.set_ylabel("Queries/second")
ax_2.set_xlabel("Medium Dataset Query Rate")
ax_3.set_ylabel("Queries/second")
ax_3.set_xlabel("Large Dataset   Query Rate")
# Out:
# Text(0.5, 0, 'Large Dataset   Query Rate')

# %%
f, (ax_1, ax_2, ax_3) = plt.subplots(3,1,figsize=(9,11))
query_rate_small= np.array([7.07, 39.72])
query_rate_medium = np.array([6.45,20.79])
query_rate_large = np.array([0.43 , 6.08])

labels = np.array(["Timescale_Db","Influx"])

ax_1.bar(labels,query_rate_small, color=['royalblue', 'orchid'])
ax_2.bar(labels,query_rate_medium, color=['royalblue', 'orchid'])
ax_3.bar(labels,query_rate_large, color=['royalblue', 'orchid'])
ax_1.set_title("Query Rate for Long Driving Sessions")


ax_1.set_ylabel("Queries/second")
ax_1.set_xlabel("Small Dataset Query Rate")
ax_2.set_ylabel("Queries/second")
ax_2.set_xlabel("Medium Dataset Query Rate")
ax_3.set_ylabel("Queries/second")
ax_3.set_xlabel("Large Dataset   Query Rate")
# Out:
# Text(0.5, 0, 'Large Dataset   Query Rate')

# %%
f, (ax_1, ax_2, ax_3) = plt.subplots(3,1,figsize=(9,11))
query_rate_small= np.array([0.06, 10.80])
query_rate_medium = np.array([0.01,4.96])
query_rate_large = np.array([0.02 , 2.60])

labels = np.array(["Timescale_Db","Influx"])

ax_1.bar(labels,query_rate_small, color=['royalblue', 'orchid'])
ax_2.bar(labels,query_rate_medium, color=['royalblue', 'orchid'])
ax_3.bar(labels,query_rate_large, color=['royalblue', 'orchid'])
ax_1.set_title("Query Rate for High Load")


ax_1.set_ylabel("Queries/second")
ax_1.set_xlabel("Small Dataset Query Rate")
ax_2.set_ylabel("Queries/second")
ax_2.set_xlabel("Medium Dataset Query Rate")
ax_3.set_ylabel("Queries/second")
ax_3.set_xlabel("Large Dataset   Query Rate")
# Out:
# Text(0.5, 0, 'Large Dataset   Query Rate')

# %%
f, (ax_1, ax_2, ax_3) = plt.subplots(3,1,figsize=(9,11))
query_rate_small= np.array([3.87, 1.53])
query_rate_medium = np.array([0.11, 0.42])
query_rate_large = np.array([0.22 , 0.16])

labels = np.array(["Timescale_Db","Influx"])

ax_1.bar(labels,query_rate_small, color=['royalblue', 'orchid'])
ax_2.bar(labels,query_rate_medium, color=['royalblue', 'orchid'])
ax_3.bar(labels,query_rate_large, color=['royalblue', 'orchid'])
ax_1.set_title("Query Rate for Avg Projected Fuel Consumption")


ax_1.set_ylabel("Queries/second")
ax_1.set_xlabel("Small Dataset Query Rate")
ax_2.set_ylabel("Queries/second")
ax_2.set_xlabel("Medium Dataset Query Rate")
ax_3.set_ylabel("Queries/second")
ax_3.set_xlabel("Large Dataset   Query Rate")
# Out:
# Text(0.5, 0, 'Large Dataset   Query Rate')

# %%
f, (ax_1, ax_2, ax_3) = plt.subplots(3,1,figsize=(9,11))
query_rate_small= np.array([1.56, 0.53])
query_rate_medium = np.array([0.07, 0.11])
query_rate_large = np.array([0.08 , 0.03])

labels = np.array(["Timescale_Db","Influx"])

ax_1.bar(labels,query_rate_small, color=['royalblue', 'orchid'])
ax_2.bar(labels,query_rate_medium, color=['royalblue', 'orchid'])
ax_3.bar(labels,query_rate_large, color=['royalblue', 'orchid'])
ax_1.set_title("Query Rate for Breakdown Frequency")


ax_1.set_ylabel("Queries/second")
ax_1.set_xlabel("Small Dataset Query Rate")
ax_2.set_ylabel("Queries/second")
ax_2.set_xlabel("Medium Dataset Query Rate")
ax_3.set_ylabel("Queries/second")
ax_3.set_xlabel("Large Dataset   Query Rate")
# Out:
# Text(0.5, 0, 'Large Dataset   Query Rate')

# %%
f, (ax_1, ax_2, ax_3) = plt.subplots(3,1,figsize=(9,11))
disk_size_small= np.array([avg_query_duration_IoT_timescale_small,  avg_query_duration_IoT_influx_small])
disk_size_medium = np.array([avg_query_duration_IoT_timescale_medium,  avg_query_duration_IoT_influx_medium])
disk_size_large = np.array([avg_query_duration_IoT_timescale_large, avg_query_duration_IoT_influx_large])

labels = np.array(["Timescale_Db","Influx"])

ax_1.bar(labels,disk_size_small, color=['royalblue', 'orchid'])
ax_2.bar(labels,disk_size_medium, color=['royalblue', 'orchid'])
ax_3.bar(labels,disk_size_large, color=['royalblue', 'orchid'])
ax_1.set_title("Average Query Rate")


ax_1.set_ylabel("Queries/second")
ax_1.set_xlabel("Small Dataset Average Query Rate")
ax_2.set_ylabel("Queries/second")
ax_2.set_xlabel("Medium Dataset Average Query Rate")
ax_3.set_ylabel("Queries/second")
ax_3.set_xlabel("Large Dataset Average Query Rate")
# Out:
# Text(0.5, 0, 'Large Dataset Average Query Rate')

# %%
f, (ax_1, ax_2, ax_3) = plt.subplots(3,1,figsize=(8,11))
disk_size_small= np.array([avg_query_duration_devops_timescale_small,  avg_query_duration_devops_influx_small])
disk_size_medium = np.array([avg_query_duration_devops_timescale_medium,  avg_query_duration_devops_influx_medium])
disk_size_large = np.array([avg_query_duration_devops_timescale_large, avg_query_duration_devops_influx_large])

labels = np.array(["Timescale_Db","Influx"])

ax_1.bar(labels,disk_size_small, color=['royalblue', 'orchid'])
ax_2.bar(labels,disk_size_medium, color=['royalblue', 'orchid'])
ax_3.bar(labels,disk_size_large, color=['royalblue', 'orchid'])
ax_1.set_title("Average Query Rate Devops")


ax_1.set_ylabel("Queries/second")
ax_1.set_xlabel("Small Dataset Average Query Rate")
ax_2.set_ylabel("Queries/second")
ax_2.set_xlabel("Medium Dataset Average Query Rate")
ax_3.set_ylabel("Queries/second")
ax_3.set_xlabel("Large Dataset Average Query Rate")
# Out:
# Text(0.5, 0, 'Large Dataset Average Query Rate')
